# %%
from cropnet.data_downloader import DataDownloader

# Use the "target_dir" to specify where the data should be downloaded to
downloader = DataDownloader(target_dir="./data/CropNet")

# Download 2022 USDA Soybean data
# Note that most of the 2023 USDA data are not yet available
downloader.download_USDA("Soybean", fips_codes=["01", "05", "04", "06", "08", "10", "12", "13", "19", "16", "17", "18", "20", "21", "22"], years=["2019", "2020", "2021"])

# Download the 2023 (the 1st and 2nd quarters) Sentinel-2 Imagery
downloader.download_Sentinel2(fips_codes=["01", "05", "04", "06", "08", "10", "12", "13", "19", "16", "17", "18", "20", "21", "22"], years=["2019", "2020", "2021"], image_type="AG")
downloader.download_Sentinel2(fips_codes=["01", "05", "04", "06", "08", "10", "12", "13", "19", "16", "17", "18", "20", "21", "22"], years=["2019", "2020", "2021"], image_type="NDVI")

# Download the 2023 (January to July) WRF-HRRR data
downloader.download_HRRR(fips_codes=["01", "05", "04", "06", "08", "10", "12", "13", "19", "16", "17", "18", "20", "21", "22"], years=["2019", "2020", "2021"])
# Out:
# Progress: [ 1/3 ], Downloading USDA Data, Year: 2019, Crop: Soybean
# Progress: [ 2/3 ], Downloading USDA Data, Year: 2020, Crop: Soybean
# Progress: [ 3/3 ], Downloading USDA Data, Year: 2021, Crop: Soybean
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 11
#       8 downloader.download_USDA("Soybean", fips_codes=["1", "5", "4", "6", "8", "10", "12", "13", "19", "16", "17", "18", "20", "21", "22"], years=["2019", "2020", "2021"])
#      10 # Download the 2023 (the 1st and 2nd quarters) Sentinel-2 Imagery
# ---> 11 downloader.download_Sentinel2(fips_codes=["1", "5", "4", "6", "8", "10", "12", "13", "19", "16", "17", "18", "20", "21", "22"], years=["2019", "2020", "2021"], image_type="AG")
# ...
